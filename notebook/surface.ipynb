# %%
import surface as sf
import numpy as np
import matplotlib.pyplot as plt

s = sf.EvenAsphere(r=29.324,
                        k=0.3518,
                        coefs=[-0.1071e-5, -0.1440e-8, -0.3022e-12, -0.5736e-14, 0.59e-17,-0.1142e-19])
h = np.arange(0,25,0.25)
s.print_data(h)

plt.plot(h,s.sag(h))
# Out:
# 0.0000 0.0000 0.0000 29.3240
# 0.2500 0.0011 0.4885 29.3236
# 0.5000 0.0043 0.9770 29.3223
# 0.7500 0.0096 1.4656 29.3201
# 1.0000 0.0171 1.9544 29.3171
# 1.2500 0.0267 2.4434 29.3131
# 1.5000 0.0384 2.9326 29.3084
# 1.7500 0.0523 3.4222 29.3027
# 2.0000 0.0683 3.9120 29.2962
# 2.2500 0.0865 4.4023 29.2888
# 2.5000 0.1068 4.8931 29.2805
# 2.7500 0.1293 5.3843 29.2713
# 3.0000 0.1539 5.8761 29.2612
# 3.2500 0.1807 6.3686 29.2503
# 3.5000 0.2097 6.8616 29.2384
# 3.7500 0.2409 7.3554 29.2256
# 4.0000 0.2743 7.8500 29.2119
# 4.2500 0.3098 8.3454 29.1973
# 4.5000 0.3476 8.8417 29.1818
# 4.7500 0.3876 9.3390 29.1652
# 5.0000 0.4299 9.8372 29.1477
# 5.2500 0.4743 10.3365 29.1293
# 5.5000 0.5211 10.8369 29.1098
# 5.7500 0.5700 11.3385 29.0893
# 6.0000 0.6213 11.8414 29.0677
# 6.2500 0.6749 12.3455 29.0451
# 6.5000 0.7308 12.8511 29.0214
# 6.7500 0.7890 13.3580 28.9965
# 7.0000 0.8495 13.8665 28.9705
# 7.2500 0.9124 14.3766 28.9434
# 7.5000 0.9777 14.8884 28.9150
# ...
